# %%
from PIL import Image

# %%
mac = Image.open('me.jpg')

# %%
type(mac)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
mac[0]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-16-a5c38fbeb1a5> in <module>
# ----> 1 mac[0]
#
# TypeError: 'JpegImageFile' object is not subscriptable

# %% [markdown]
# mac.size

# %%
mac.size
# Out:
# (720, 1280)

# %%
mac.filename
# Out:
# 'me.jpg'

# %%
mac.crop((20,200,700,1200))
# Out:
# <PIL.Image.Image image mode=RGB size=680x1000 at 0x7F2F6D77C6D8>

# %%
mac.putalpha(180)
